# %%
import pandas as pd
import numpy as np
import vizro.plotly.express as px
import plotly.io as pio
from datasets import Dataset
import torch
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
from sklearn.feature_extraction.text import CountVectorizer
from bertopic import BERTopic
from umap import UMAP
import hdbscan
from tqdm.auto import tqdm
from data_cleaning_and_utilities import plot_preset, get_earth_colorscale

# %% [markdown]
# ### Data loading

# %%
path = "../data/cleaned_reviews.csv"
df = pd.read_csv(path)

# %%
# Set up plot vizual
pio.templates.default = "vizro_dark"
earth_palette = get_earth_colorscale()

# %% [markdown]
# # Sentiment analysis with BERT

# %% [markdown]
# ### Model Setup and Tokenization

# %%
# Mutlilinguar BERT model that analyzes sentiment and can differentiate uppercase and lowercase
model_name = "nlptown/bert-base-multilingual-uncased-sentiment"
# Set up model to use gpu
device = 0 if torch.cuda.is_available() else -1  
# Set up automatic tokenizer to convert reviews to be usable by model
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Load the model
model = AutoModelForSequenceClassification.from_pretrained(model_name)
# Set up pipeline to analyze reviews
sentiment_pipeline = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer, device=device)
# Out:
# Device set to use cuda:0

# %% [markdown]
# ### Apply Model to Dataset

# %%
# Convert dataset to a Hugging Face Dataset
hf_dataset = Dataset.from_dict({"text": df["text"].astype(str).tolist()})

print(f"Running BERT on {len(hf_dataset)} reviews")

# Run the pipeline on all reviews at once with batching 
results = sentiment_pipeline(hf_dataset["text"], batch_size=64)

# Add results back to DataFrame
df["bert_sentiment"] = [r["label"] for r in results]
df["bert_score"] = [r["score"] for r in results]
# Out:
# Running BERT on 12420 reviews

# %% [markdown]
# ### Map and Normalize Sentiment Labels

# %%
# Remap the score for comparison
map_real = {
    "5 star rating" : "5",
    "4 star rating" : "4",
    "3 star rating" : "3",
    "2 star rating" : "2",
    "1 star rating" : "1"
}
map_bert = {
    "5 stars" : "5",
    "4 stars" : "4",
    "3 stars" : "3",
    "2 stars" : "2",
    "1 star" : "1"
}

df["score"]= df["score"].map(map_real)
df["bert_sentiment"] = df["bert_sentiment"].map(map_bert)

# Convers rating to float type
df[["score", "bert_sentiment"]] = df[["score", "bert_sentiment"]].astype("float")

# %% [markdown]
# ### Compare users and BERT averages

# %%
# Calculate averages of user and BERT scores
reviewers_score_mean = df["score"].mean()
bert_score_mean = df["bert_sentiment"].mean()

print(f"Review score mean - {reviewers_score_mean:.2f}")
print(f"Bert score mean is - {bert_score_mean:.2f}")
# Out:
# Review score mean - 4.53
# Bert score mean is - 4.33

# %% [markdown]
# ### Compare user and BERT sentiment distribution

# %%
# Calculate users and BERT sentiment distribution
user_rating = df["score"].value_counts().reset_index()
user_rating.columns = ["Score", "Count"]
bert_rating = df["bert_sentiment"].value_counts().reset_index()
bert_rating.columns = ["Score", "Count"]
# Visualize BERT sentiment distribution across rating with pie chart
fig = px.pie(user_rating , values="Count", names="Score", title="Users Score Distribution", color_discrete_sequence=earth_palette)
fig = plot_preset(fig)
# Adjust legend position
fig.update_layout(
    legend=dict(
        orientation="h",            
        yanchor="bottom", y=-0.2,   
        xanchor="center", x=0.5     
    )
);
fig = px.pie(bert_rating, values="Count", names="Score", title="BERT Score Distribution", color_discrete_sequence=earth_palette)
fig = plot_preset(fig)
fig.update_layout(
    legend=dict(
        orientation="h",            
        yanchor="bottom", y=-0.2,   
        xanchor="center", x=0.5     
    )
);

# %% [markdown]
# ### Calculating mismatch percentage per score

# %%
# Flag reviews where the user-provided score and BERT-predicted sentiment disagree
df["mismatch"] = df["score"] != df["bert_sentiment"]

# Extract only the rows where a mismatch occurs
mismatches = df[df["mismatch"]]

# Count the number of mismatched reviews for each user-provided score
count_per_score = mismatches.groupby("score")["review_id"].count().reset_index()

# Count the total number of reviews for each user-provided score
total_reviews = df.groupby("score")["review_id"].count().reset_index()

# Merge mismatch counts with total review counts by score
count_per_score = pd.merge(count_per_score, total_reviews, on="score", how="right")

# Calculate what percentage of all mismatches belong to each score category
count_per_score["percentages"] = round(count_per_score["review_id_x"] / count_per_score["review_id_x"].sum() * 100, 2)

# Calculate the mismatch rate within each score category
count_per_score["percentages_2"] = round(count_per_score["review_id_x"] / count_per_score["review_id_y"] * 100, 2)

# Rename columns for better readability in the final output
count_per_score.columns = [
    "Score",
    "Mismatched review amount",
    "Total review amount",
    "% of All Mismatch",
    "% Mismatch per Score"
]

# Save the mismatch statistics to a CSV file for reporting or further analysis
output_path = (current_working_directory / "../data/BERT_mismatch_data.csv").resolve()
count_per_score.to_csv(output_path, index=False)

# Preview the result
count_per_score.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 32
#      23 count_per_score.columns = [
#      24     "Score",
#      25     "Mismatched review amount",
#    (...)     28     "% Mismatch per Score"
#      29 ]
#      31 # Save the mismatch statistics to a CSV file for reporting or further analysis
# ---> 32 output_path = (current_working_directory / "../data/BERT_mismatch_data.csv").resolve()
#      33 count_per_score.to_csv(output_path, index=False)
#      35 # Preview the result
#
# NameError: name 'current_working_directory' is not defined

# %%
# Visualize total reviews and mismatch percentages per score using a grouped bar chart
fig = px.bar(count_per_score, x="Score", y=["Total review amount", "Mismatched review amount"], barmode="group", labels={"variable": "Metric"}, 
             title="Mismatch Metrics by Review Score(Log scale)", log_y = True, color_discrete_sequence=earth_palette,)
fig = plot_preset(fig)
fig.update_layout(
   yaxis_title = "Review Amount",
   yaxis_tickvals = ["250", "500", "1000", "1700", "3000", "5500", "10000"],
   yaxis_ticktext = ["250", "500", "1000", "1700", "3000", "5500", "10000"]
);

# %% [markdown]
# ### Heatmap showcasing results

# %%
# Create confusion matrix
confusion = pd.crosstab(df["score"], df["bert_sentiment"])
# Apply log scaling for better color distribution
confusion_log = np.log1p(confusion)

# Plot the heatmap
fig = px.imshow(
    confusion_log,
    labels=dict(x="BERT Star Rating", y="User Star Rating"),
    x=confusion.columns.astype(str),
    y=confusion.index.astype(str),
    color_continuous_scale="Viridis",
)

# Add raw counts as annotations
fig.update_traces(
    text=confusion.values,
    texttemplate="%{text}",
    textfont={"size": 12, "color": "black"}
)
fig = plot_preset(fig)
fig.update_layout(
    title={
        "text": "User Ratings vs BERT Predicted Ratings",
        "x": 0.45,  
        "xanchor": "center"
    }
);

# %%
# Calculate the average user rating by size feedback category
size_users = df.groupby("size")["score"].mean().reset_index()

# Calculate the average BERT-predicted sentiment by size feedback category
size_bert = df.groupby("size")["bert_sentiment"].mean().reset_index()

# Merge both sets of averages into one DataFrame
size_analisys = pd.merge(size_users, size_bert, on="size", how="right")

# Rename columns for clarity
size_analisys.columns = ["Size Feedback", "User Score", "BERT Score"]

# Calculate the difference (drift) between user score and BERT sentiment
size_analisys["Drift (Score - Sentiment)"] = size_analisys["User Score"] - size_analisys["BERT Score"]

# Reshape the DataFrame for grouped bar plotting
size_analisys = size_analisys.melt(
    id_vars="Size Feedback",
    value_vars=["User Score", "BERT Score"],
    var_name="Metric",
    value_name="Value"
)

# Plot average scores by size feedback
fig = px.bar(
    size_analisys,
    x="Size Feedback",
    y="Value",
    color="Metric",
    barmode="group",
    color_discrete_sequence=earth_palette,
    title="Users Rate Higher Than They Feel: Size Feedback vs. Review Sentiment"
)

fig = plot_preset(fig)
fig.update_layout(
    xaxis_title="Metric",
    yaxis_title="Average Score"
);

# %% [markdown]
# ### Review Length

# %%
# Aggregate average review length, BERT sentiment, user score, and count by size feedback
dft = df.groupby("size").agg({
    "review_length": "mean",
    "bert_sentiment": "mean",
    "score": "mean",
    "review_id": "count"
}).reset_index()

# Plot review length distribution across size categories
fig = px.box(dft, y="review_length",  color_discrete_sequence=['#F1B555'])
fig = plot_preset(fig)
fig.update_layout(
    yaxis_title="Review Length",
    width=415
);

# %% [markdown]
# ### Average review length by category

# %%
# Group by product category and compute total review length and number of reviews
dfc = df[["main_category", "review_length", "review_id"]]
dfc = dfc.groupby("main_category").agg({
    "review_length": "sum",
    "review_id": "count"
}).reset_index()

# Calculate average review length per review
dfc["avg_review_length"] = round(dfc["review_length"] / dfc["review_id"], 2)

# Sort by average length for better visual ranking
dfc = dfc.sort_values("avg_review_length", ascending=True)

# Plot horizontal bar chart of average review length by category
fig = px.bar(
    dfc,
    x="avg_review_length",
    y="main_category",
    orientation="h",
    text="avg_review_length",
    color="main_category",
    title="Average Review Length by Product Category",
    color_discrete_sequence=earth_palette
)

fig.update_traces(textposition="outside")
fig = plot_preset(fig)
fig.update_layout(
    xaxis_title="Avg. Review Length (Characters)",
    yaxis_title="Product Category",
    showlegend=False,
    width=1100
);

# %% [markdown]
# ### Review mismatch per main category

# %%
# Select relevant columns and create a copy for mismatch analysis by category
dfc = df[["main_category", "review_id", "score", "bert_sentiment"]].copy()

# Flag mismatches between user rating and BERT sentiment
dfc["mismatches"] = dfc["score"] != dfc["bert_sentiment"]
dfc = dfc.rename(columns = {"review_id" : "Review Amount", "mismatches" : "Mismatches"})
# Drop raw score columns to focus on counts and mismatches
dfc = dfc.drop(["score", "bert_sentiment"], axis=1)

# Group by product category and aggregate total reviews and mismatch counts
dfc = dfc.groupby("main_category").agg({
    "Review Amount": "count",
    "Mismatches": "sum"
}).reset_index()

# Plot grouped bar chart of total reviews vs mismatches per product category
fig = px.bar(dfc, x="main_category", y=["Review Amount", "Mismatches"], barmode="group", title="Review vs Mismatch Count by Product Category(Log scale for Review Amount)", log_y=True,
    color_discrete_sequence=earth_palette
)

fig = plot_preset(fig)

# Update axis labels and customize tick values for clarity
fig.update_layout(
    xaxis_title="Product Category",
    yaxis_title="Review Amount",
    yaxis_tickvals=["30", "100", "250", "500", "1000", "2000", "5000", "10000"],
    yaxis_ticktext=["30", "100", "250", "500", "1000", "2000", "5000", "10000"]
);

# %% [markdown]
# # Aspect-Based Sentiment Analysis

# %%
# Extract keywords from reviews using bag of words model
# Ensure data type
df["text"] = df["text"].fillna("").astype(str)

# Initialize vectorizer
vectorizer = CountVectorizer(stop_words="english", max_features=1000)

# Fit and transform text data
X = vectorizer.fit_transform(df["text"])

# Sum word frequencies
word_freq = X.sum(axis=0).A1

# Get words
vocab = vectorizer.get_feature_names_out()

# Build DataFrame
freq_df = pd.DataFrame({"word": vocab, "count": word_freq})

# Sort by count
freq_df = freq_df.sort_values(by="count", ascending=False).reset_index(drop=True)

freq_df.head(200).to_string("top_words.txt")

# %%
# Create aspect keyword disctinory and list based on bag of words model using top_words.txt
aspect_keywords = {
    "size_and_fit": [
        "size", "fit", "small", "half", "wide", "big", "tight", "narrow", "fits",
        "runs", "sizing", "bigger", "smaller", "snug", "room", "sized", "too small",
        "too big", "toe", "strap", "toes", "calves", "calf", "straps", "ankle"
    ],
    "comfort": [
        "comfortable", "comfy", "feet", "feel", "soft", "uncomfortable", "comfort", "worn"
    ],
    "style_and_appearance": [
        "cute", "look", "stylish", "beautiful", "color", "style", "black", "nice",
        "pretty", "dress", "gorgeous", "classy", "red", "casual", "white", "brown",
        "sexy", "outfit", "looks", "looking", "design"
    ],
    "quality_and_material": [
        "quality", "leather", "material", "suede", "stiff"
    ],
    "wearability": [
        "wear", "walk", "long", "wore", "walking", "day", "hours", "short"
    ],
    "price_and_value": [
        "price", "expensive", "affordable", "worth", "value", "cheap", "overpriced"
    ],
    "delivery": [
        "delivery", "shipping", "arrived", "fast", "slow", "late", "package"
    ]
}
shoe_type_keywords = [
    "sandals", "heels", "sneakers", "loafers", "flats", "boots", 
    "platforms", "wedges", "slides", "mules"
]

# %%
# Create columns in main dataframe with keyword aspects
def detect_aspects(text, aspect_keywords):
    text = text.lower()
    detected = []
    for aspect, keywords in aspect_keywords.items():
        if any(kw in text for kw in keywords):
            detected.append(aspect)
    return detected
df["detected_aspects"] = df["text"].apply(lambda x: detect_aspects(x, aspect_keywords))

def detect_shoe_type(text, shoe_type_keywords):
    text = str(text).lower()
    for keyword in shoe_type_keywords:
        if keyword in text:
            return keyword  
    return None 
df["detected_shoe_type"] = df["text"].apply(lambda x: detect_shoe_type(x, shoe_type_keywords))

# %%
# Explode the 'detected_aspects' list column so each aspect has its own row
df_exploded = df.explode("detected_aspects")
# Filter out review with no aspects 
df_exploded = df_exploded[df_exploded["detected_aspects"].notna()]

# Assign setiment label to each aspect based on bert sentiment
def sentiment_label(score):
    if score >= 4:
        return "Positive"
    elif score <= 2:
        return "Negative"
    else:
        return "Neutral"

df_exploded["aspect_sentiment"] = df_exploded["bert_sentiment"].apply(sentiment_label)

# %%
# Group the exploded review data by aspect and sentiment, count occurrences, pivot to wide format
df_aspects = df_exploded.groupby(["detected_aspects", "aspect_sentiment"]).size().unstack(fill_value=0).reset_index()

# Calculate sentiment percentages for each aspect
df_aspects["Negative_%"] = (df_aspects["Negative"] / (df_aspects["Negative"] + df_aspects["Neutral"] + df_aspects["Positive"]) * 100)
df_aspects["Neutral_%"] = (df_aspects["Neutral"] / (df_aspects["Negative"] + df_aspects["Neutral"] + df_aspects["Positive"]) * 100)
df_aspects["Positive_%"] = (df_aspects["Positive"] / (df_aspects["Negative"] + df_aspects["Neutral"] + df_aspects["Positive"]) * 100)

# Convert absolute sentiment counts and sentiment percentages to long format for plotting
df_aspects_raw = df_aspects.melt(id_vars="detected_aspects", value_vars=["Negative", "Neutral", "Positive"], var_name="Aspects", value_name="Count")

df_aspects_percentages = df_aspects.melt(id_vars="detected_aspects", value_vars=["Negative_%", "Neutral_%", "Positive_%"], var_name="Aspects", value_name="Percentage")

# Create a bar chart showing sentiment count per aspect (log-scaled Y axis for readability)
fig = px.bar(df_aspects_raw, x="detected_aspects", y="Count", color="Aspects",log_y=True,
    color_discrete_sequence=earth_palette, barmode="group", title="Aspect-Level Breakdown of Sentiment in Reviews"
)

# Update chart layout for clarity and consistent scaling
fig.update_layout(
    xaxis_title="Product Aspect Category",
    yaxis_title="Review Count (Log Scale)",
    yaxis_tickvals=[0, 20, 50, 100, 250, 500, 1000, 1700, 3000, 5000, 8000]
);

# Create a bar chart showing sentiment percentage per aspect
fig = px.bar(df_aspects_percentages, x="detected_aspects", y="Percentage", color="Aspects",
    color_discrete_sequence=earth_palette, barmode="group", title="Aspect-Level Breakdown of Sentiment in Reviews"
)

fig.update_layout(
    xaxis_title="Product Aspect Category",
    yaxis_title="Review Percentage"
);

# %%
# Explode the 'detected_shoe_type' list column so each aspect has its own row
df_exploded_shoe = df.explode("detected_shoe_type")

# Filter out review with no aspects 
df_exploded = df_exploded_shoe[df_exploded_shoe["detected_shoe_type"].notna()]

df_exploded["shoe_type_sentiment"] = df_exploded["bert_sentiment"].apply(sentiment_label)

# %%
# Group the exploded review data by aspect and sentiment, count occurrences, pivot to wide format
df_aspects = df_exploded.groupby(["detected_shoe_type", "shoe_type_sentiment"]).size().unstack(fill_value=0).reset_index()
# Convert absolute sentiment counts and sentiment percentages to long format for plotting
df_aspects = df_aspects.melt(id_vars="detected_shoe_type", value_vars=["Negative", "Neutral", "Positive"], var_name="Aspects", value_name="Count")
# Create a bar chart showing sentiment count per aspect (log-scaled Y axis for readability)
fig = px.bar(df_aspects, x="detected_shoe_type", y="Count", color="Aspects",log_y=True,
    color_discrete_sequence=earth_palette, barmode="group", title="Aspect-Level Breakdown of Sentiment in Reviews"
)

# Update chart layout for clarity and consistent scaling
fig.update_layout(
    xaxis_title="Product Aspect Category",
    yaxis_title="Review Count (Log Scale)",
    yaxis_tickvals=[0, 2, 5, 10, 25, 50, 100, 250, 500, 1000]
);

# %% [markdown]
# # BERTopic

# %%
# Remove NaNs and short reviews
df = df[df["text"].notna()]
df = df[df["text"].str.len() > 20]
df = df.reset_index(drop=True) 
# Apply BERTopic
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine', random_state=9)
hdbscan_model = hdbscan.HDBSCAN(min_cluster_size=10, metric='euclidean', prediction_data=True)

topic_model = BERTopic(umap_model=umap_model, hdbscan_model=hdbscan_model, language="english", min_topic_size=10, verbose=True)
topics, probs = topic_model.fit_transform(df["text"])

# Get topic info
df["topic"] = topics
df["topic_prob"] = probs
topic_info = topic_model.get_topic_info()
# Out:
# 2025-07-10 10:26:02,522 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/340 [00:00<?, ?it/s]
# 2025-07-10 10:26:13,598 - BERTopic - Embedding - Completed ✓
# 2025-07-10 10:26:13,599 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-07-10 10:26:39,241 - BERTopic - Dimensionality - Completed ✓
# 2025-07-10 10:26:39,243 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-07-10 10:26:39,638 - BERTopic - Cluster - Completed ✓
# 2025-07-10 10:26:39,643 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-07-10 10:26:39,908 - BERTopic - Representation - Completed ✓

# %%
#Use BERT sentiment pipeline to assign sentiment scores
tqdm.pandas()
hf_dataset = Dataset.from_dict({"text": df["text"].astype(str).tolist()})

# Define sentiment function using your pipeline
def get_sentiment_label(example):
    result = sentiment_pipeline(example["text"][:512])
    label = result[0]['label']
    stars = int(label.split()[0])
    if stars >= 4:
        return {"sentiment_label": "Positive"}
    elif stars == 3:
        return {"sentiment_label": "Neutral"}
    else:
        return {"sentiment_label": "Negative"}

# Apply the function to the dataset (batched=False because we use single texts)
hf_dataset = hf_dataset.map(get_sentiment_label)

# Convert back to pandas and merge with your original DataFrame
df["sentiment_label"] = hf_dataset["sentiment_label"]
# Out:
# Map:   0%|          | 0/10855 [00:00<?, ? examples/s]
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
# Prepare a list to collect topic summary data
topic_summaries = []
for row in topic_info.itertuples():
    if row.Topic == -1:
        continue  # Skip outliers/no-topic

    # Extract topic metadata
    topic_num = row.Topic
    topic_name = row.Name
    topic_count = row.Count
    topic_keywords = row.Representation

    # Filter and sort reviews assigned to this topic by confidence
    topic_reviews_df = df[df["topic"] == topic_num][["text", "topic_prob", "sentiment_label"]].dropna()
    topic_reviews_df = topic_reviews_df.sort_values("topic_prob", ascending=False)

    # Aggregate sentiment counts and compute percentages
    sentiment_counts = topic_reviews_df["sentiment_label"].value_counts()
    total = sentiment_counts.sum()
    pos_sent = sentiment_counts.get("Positive", 0) / total * 100
    neu_sent = sentiment_counts.get("Neutral", 0) / total * 100
    neg_sent = sentiment_counts.get("Negative", 0) / total * 100

    # Output topic summary details
    print(f"Topic Name and Number: {topic_name}")
    print(f"Review count - {topic_count}")
    print(f"Keywords - {topic_keywords}")
    print(f"Sentiment distribution: Positive: {pos_sent:.1f}%, Neutral: {neu_sent:.1f}%, Negative: {neg_sent:.1f}%")

    # Extract and print the top 5 most confident reviews
    most_confident_reviews = topic_reviews_df.head(5)["text"]
    print("Most Confident Reviews:")
    for i, review in enumerate(most_confident_reviews, 1):
        print(f"{i}. {review.strip()[:300]}")
    print("\n")

    # Store all topic-level insights into a summary dictionary
    topic_summaries.append({
        "Topic Number": topic_num,
        "Topic Name": topic_name,
        "Review Count": topic_count,
        "Keywords": topic_keywords,
        "Positive %": round(pos_sent, 1),
        "Neutral %": round(neu_sent, 1),
        "Negative %": round(neg_sent, 1)
    })

# Create a DataFrame with all topic summaries for further analysis and visualization
topic_summary_df = pd.DataFrame(topic_summaries)
topic_summary_df.head()
# Out:
# Topic Name and Number: 0_shoes_these_are_love
# Review count - 381
# Keywords - ['shoes', 'these', 'are', 'love', 'comfortable', 'absolutely', 'cute', 'comfy', 'so', 'and']
# Sentiment distribution: Positive: 95.3%, Neutral: 3.4%, Negative: 1.3%
# Most Confident Reviews:
# 1. The animal print is cute detail when shoes are off. They are comfy & can be used for almost any shoe-flats & any low heeled styles. Using these for SM boots I bought (Ryder).
# 2. While these are cute they are also comfy. A bit clunky but are stylish as well. Have had many compliments on my jelly shoes!
# 3. These are cute and comfortable socks that are a fashion must have, especially when you don't want white socks peeking out from your shoes!
# 4. I absolutely love these shoes. They are so comfortable. I went to the zoo and wore these sandals, I was very comfortable the entire day! I was very surprised, as usually thicker wedge sandals would hurt my feet. These are the best pair!!!
# 5. I was drawn in by the design of the shoe and I was pleased at how comfortable they are as well!
#
#
# Topic Name and Number: 1_comfortable_them_comfy_are
# Review count - 357
# Keywords - ['comfortable', 'them', 'comfy', 'are', 'love', 'cute', 'they', 'super', 'uncomfortable', 'very']
# Sentiment distribution: Positive: 86.3%, Neutral: 4.2%, Negative: 9.5%
# Most Confident Reviews:
# 1. i wore these one time. they are super comfortable. after one wear, they got multiple holes in the front of the ped. this is with a short pedicure. it is like they need an extra liner in the front. i bought 3 pairs. it happened to the second pair on the first wear as well. steve madden did not want t
# 2. I just love it !! They are very soft and cute 🥰
# 3. No concerns. I love them
# 4. I finally got them! Material is so good, very comfortable and aren’t tiring at all. They’re giving 70s vibes lol
# 5. They are super cute and surprisingly comfortable.
#
#
# Topic Name and Number: 2_boots_these_love_them
# Review count - 329
# Keywords - ['boots', 'these', 'love', 'them', 'are', 'comfortable', 'so', 'absolutely', 'theyre', 'quality']
# Sentiment distribution: Positive: 95.4%, Neutral: 1.8%, Negative: 2.7%
# Most Confident Reviews:
# 1. Great to wear with clogs,mules and boots. Love!!
# 2. Love! Wish the bottoms had a little better grip. Great for work or casual
# 3. Was very scary bc the reviews about the quality, actually ordered first a pair of boots, beautiful but the quality wasn’t the best very plastic. But this tennis are just gorgeous, very comfortable and the quality is good.
# 4. Love the way they look with long pants, short skirt, can be worn so many ways. Nice boots.
# 5. Perfect for shooes or boots. Not too thick. And stylish.
#
#
# Topic Name and Number: 3_sandals_are_these_summer
# Review count - 242
# Keywords - ['sandals', 'are', 'these', 'summer', 'they', 'comfortable', 'and', 'love', 'pair', 'so']
# Sentiment distribution: Positive: 90.1%, Neutral: 5.4%, Negative: 4.5%
# Most Confident Reviews:
# 1. I love these sandals! Very stylish, can be dresses up or down. They do, however, run a little small. I'm a size 6 and barely made it. They don't come in half sizes, which is disappointing. Also, if you have a wide foot, the footbed may rub or press on the sides of your feet. I'm hoping once they bre
# 2. These sandals are stunning! Cannot wait to get them! So excited!
# 3. Love, love, love! Theses sandals are so stylish and super comfortable! Wish they came in dark brown.
# 4. Very comfortable sandals. Yes I recommend this product.
# 5. The sandals are really comfortable and stylish. My favorite pair for this summer. The neutral color goes with everything. I love it!
#
#
# Topic Name and Number: 4_wide_narrow_feet_foot
# Review count - 229
# Keywords - ['wide', 'narrow', 'feet', 'foot', 'width', 'have', 'if', 'you', 'shoe', 'wider']
# Sentiment distribution: Positive: 40.2%, Neutral: 29.7%, Negative: 30.1%
# Most Confident Reviews:
# 1. I love this style and wanted to keep them so badly but bc they are so narrow, if you adjust the strap you can see the Velcro and it loses its entire look. I returned them to the store to see if sizing up would help, but same issue. I don’t have a wide foot so I’m not sure who these fit.
# 2. I loved the look of these heels, however I had to return them because I have wide feet so I don’t recommend purchasing if you also
# Have wide feet
# 3. They are so cute and go with most fits 🩷Just a little thin so if you have wide feet it might be uncomfortable for you….
# 4. These did not fit my feet width. They seemed more for folks who have thinner/slender feet. They are beautiful though.
# 5. These shoes are fantastic! They fit great, are easy to walk in, feel great, and are SO cute. I love that the strap hold my foot in place and they form to your feet after a few wears. They fit my feet quite snugly so I imagine these shoes would not fit well on wider feet.
#
#
# Topic Name and Number: 5_bag_this_it_its
# Review count - 183
# Keywords - ['bag', 'this', 'it', 'its', 'love', 'is', 'one', 'the', 'wallet', 'phone']
# Sentiment distribution: Positive: 92.3%, Neutral: 4.9%, Negative: 2.7%
# Most Confident Reviews:
# 1. Even more stunning in person. High quality material and very well put together. I got a lot of compliments when I carried this bag. I want to buy one in every color!! Would absolutely purchase again.
# 2. I absolutely love this bag it’s everything that I expected I received it as a Valentines’s gift from my husband ❤️❤️
# 3. 5/5 the bag is so nice, I love everything about it
# 4. Nice quality bag and compliments a wide variety of styles
# 5. I love the bag it’s just right
#
#
# Topic Name and Number: 6_fit_fits_great_perfect
# Review count - 164
# Keywords - ['fit', 'fits', 'great', 'perfect', 'color', 'perfectly', 'well', 'style', 'good', 'and']
# Sentiment distribution: Positive: 97.0%, Neutral: 2.4%, Negative: 0.6%
# Most Confident Reviews:
# 1. fits perfectly well i love it can’t wait to wear
# 2. Fit great and very comfortable for walking.
# 3. Good fit and comfortable
# 4. Great fit, looked great, simple yet elegant
# 5. Fit and look are perfect
#
#
# Topic Name and Number: 7_uncomfortable_hurt_feet_shoes
# Review count - 145
# Keywords - ['uncomfortable', 'hurt', 'feet', 'shoes', 'hours', 'walk', 'wore', 'toes', 'walking', 'them']
# Sentiment distribution: Positive: 48.3%, Neutral: 11.0%, Negative: 40.7%
# Most Confident Reviews:
# 1. They stain your feet’s
# 2. Get these shoes, they are soo comfy. I've walked in these sandals for hours with no pain. Comfortable, stylish and a good price, get them ladies!
# 3. These shoes are so uncomfortable, they have no give and when you walk they are as stiff as a board making it uncomfortable to walk anything further than a block. I would return them but they don’t accept in store returns in Colorado :/
# 4. Tried them on hurt between toes but love the style of the shoes
# 5. These are very cute aesthetically, but not practical for wearing long periods of time. The part that separates the toes is extremely painful after walking in them for so long. I wore them to a wedding and had to take them off immediately after the ceremony because of the excruciating pain. My ankles
#
#
# Topic Name and Number: 8_sandal_summer_this_the
# Review count - 139
# Keywords - ['sandal', 'summer', 'this', 'the', 'for', 'it', 'is', 'of', 'cute', 'strap']
# Sentiment distribution: Positive: 79.1%, Neutral: 9.4%, Negative: 11.5%
# Most Confident Reviews:
# 1. Love this sandal very comfortable received lots of compliments
# 2. This sandal was everything, you could dress it up or down. Got so many compliments and it was true to the size.
# 3. The sandal is cute and definitely comfortable to wear all day, and it isn’t heavy on the foot.
# 4. It looks heavy but very light when I use it. It is true to size. I have a lot of compliments , one time someone stop me to ask where I bought this sandal.
# 5. The perfect summer sandal. So comfy and cute. You can wear with just about anything. 10 out of 10 recommend buying!!
#
#
# Topic Name and Number: 9_boot_this_bootie_is
# Review count - 138
# Keywords - ['boot', 'this', 'bootie', 'is', 'beautiful', 'great', 'it', 'nice', 'very', 'looks']
# Sentiment distribution: Positive: 88.4%, Neutral: 5.1%, Negative: 6.5%
# Most Confident Reviews:
# 1. Love the boot very comfortable!
# 2. Very nice boot, just more red than wine.
# 3. Beautiful boot, nice fit, the color is awesome
# 4. This Boot is Beautiful ❤️
# 5. Comfortable and stylish! Love this boot!
#
#
# Topic Name and Number: 10_black_colors_white_color
# Review count - 137
# Keywords - ['black', 'colors', 'white', 'color', 'shoes', 'shoe', 'in', 'this', 'pair', 'of']
# Sentiment distribution: Positive: 86.1%, Neutral: 8.8%, Negative: 5.1%
# Most Confident Reviews:
# 1. I love these shoe so much I ordered two colors
# 2. Obsessed! I have these in the multi color and denim. They are very comfortable. Only con is the sole has a weird arch, maybe it’s just my foot?
# 3. Very impressed with the comfort of the shoe! Definitely would purchase another color in this shoe.
# 4. I love these sandals!! Second pair purchased. I have two others in my cart!! I want them in every color!!
# 5. I adore this line of shoes by Steve Madden. I have two pairs of Big Mona - black & multi color and have the beige/sand and now black suede of this line. So cute! Buy them!
#
#
# Topic Name and Number: 11_madden_steve_shoes_from
# Review count - 132
# Keywords - ['madden', 'steve', 'shoes', 'from', 'maddens', 'always', 'of', 'this', 'years', 'pair']
# Sentiment distribution: Positive: 83.3%, Neutral: 6.1%, Negative: 10.6%
# Most Confident Reviews:
# 1. I love all Steve Madden shoes
# 2. MADDEN shoes have NEVER disappointed me!
# 3. Steven madden sneakers
# 4. loved the shoes, and Steve Madden return is the best,
# 5. Goes great with the green Steve Madden shoes
#
#
# Topic Name and Number: 12_true_size_shoe_pictured
# Review count - 129
# Keywords - ['true', 'size', 'shoe', 'pictured', 'shoes', 'to', 'is', 'exactly', 'as', 'comfortable']
# Sentiment distribution: Positive: 86.0%, Neutral: 9.3%, Negative: 4.7%
# Most Confident Reviews:
# 1. I absolutely love these shoes. Super comfortable and true to size.
# 2. I love these shoes. I get so many compliments! They are not only eye catching, but so comfortable! True to size.
# 3. These shoes are even more gorgeous in person!! True to size :) I can’t wait to wear them!
# 4. These are the perfect addition to anyone’s shoe collection, a must have. True to size and fit! I love them!
# 5. Loved these shoes. Fit was true to size for me. Definitely glad I purchased
#
#
# Topic Name and Number: 13_muy_la_de_son
# Review count - 124
# Keywords - ['muy', 'la', 'de', 'son', 'cmodos', 'que', 'los', 'se', 'es', 'el']
# Sentiment distribution: Positive: 85.5%, Neutral: 6.5%, Negative: 8.1%
# Most Confident Reviews:
# 1. Buena las amo espero sean duraderas
# 2. Hermosas son como plásticas, lucen hermosas
# 3. Hermosas y muy cómodas las usé para la playa
# 4. Muy Buena Calida y muy comodos
# 5. Los recomiendo al 100 me gustaron mucho muy cómodos y lindos
#
#
# Topic Name and Number: 14_heel_height_perfect_is
# Review count - 123
# Keywords - ['heel', 'height', 'perfect', 'is', 'high', 'low', 'the', 'for', 'just', 'of']
# Sentiment distribution: Positive: 88.6%, Neutral: 8.9%, Negative: 2.4%
# Most Confident Reviews:
# 1. The quality is chefs kiss! Love the suede. The heel is a perfect height! I love a kitten heel that is also fashionable. The nude color is perfect for all seasons. The shoe does run true to size.
# 2. Exactly what I've been looking for. Perfect heel height. Quality sandals. ❤️
# 3. I bought these and I thought they would be to low of a heel. I love them.
# 4. I absolutely fine these heel very nice… they are pretty tall and will make your feet hurt but other than that they look amazing and the quality is beautiful.❤️
# 5. This is the third time I buy this heel!
#
# It is so comfortable and honestly goes with everything. I mainly use it for work but when need be it is the perfect heel for a night out or for brunch with the girls. Honestly, I can not find another shoe like it, FOREVER A CUSTOMER.
#
#
# Topic Name and Number: 15_boots_size_true_to
# Review count - 119
# Keywords - ['boots', 'size', 'true', 'to', 'they', 'are', 'these', 'up', 'run', 'my']
# Sentiment distribution: Positive: 91.6%, Neutral: 5.9%, Negative: 2.5%
# Most Confident Reviews:
# 1. I love these boots and get so many compliments on them. They fit true to size and are very comfortable.
# 2. LOVE THESE BOOTS!!! True to size, wonderful style, and incredibly comfortable. Goes with anything!!! You will not regret getting a pair!!!
# 3. loveee These. Best boots I own but if you’re considering buying these, you might want to get a size or two up.
# 4. I absolutely love these boots!! I went up a half size only because I like wearing socks with my boots. I just bought them in the chestnut also!! Harness Style boots have slways been my favorites. Steve Madden did it right!!!
# 5. These boots are beautiful. The fit is great. No need to size up…
#
#
# Topic Name and Number: 16_an_85_usually_normally
# Review count - 110
# Keywords - ['an', '85', 'usually', 'normally', 'wear', 'size', '75', 'but', 'got', 'im']
# Sentiment distribution: Positive: 66.4%, Neutral: 19.1%, Negative: 14.5%
# Most Confident Reviews:
# 1. I normally wear a 8. 5 and these were more of a size 8.
# 2. I normally would've purchased an 8 but because of the reviews got a 10 and couldn't have gone any smaller. BUT because I did, they're amazing. So comfortable and getting so many compliments.
# 3. Definitely size up. I've always been an 8 and the 8 was wayyy too small. waiting on the 9 to arrive.
# 4. I wear a size 8 and that’s what I took and it fits me perfectly fine. . Everyone loves my slippers including me. . I’m so so obsessed with it
# 5. These are perfect for day trips when you want to be comfortable but also cute and stylish! I sized up to an 8.5 and I’m usually an 8. Would highly recommend!
#
#
# Topic Name and Number: 17_true_size_to_comfortable
# Review count - 105
# Keywords - ['true', 'size', 'to', 'comfortable', 'fits', 'very', 'comfy', 'fit', 'stylish', 'good']
# Sentiment distribution: Positive: 95.2%, Neutral: 4.8%, Negative: 0.0%
# Most Confident Reviews:
# 1. True to size. Wear and bought 71/2.
# 2. True to size and very comfortable. My new favorite!!!
# 3. True to size. Very comfortable to wear
# 4. True to size and the style is perfect.
# 5. True to size, Nice and comfortable feel.
# Gets a lot of compliments
#
#
# Topic Name and Number: 18_shoe_beautiful_nice_very
# Review count - 100
# Keywords - ['shoe', 'beautiful', 'nice', 'very', 'great', 'shoes', 'comfortable', 'stylish', 'quality', 'good']
# Sentiment distribution: Positive: 94.0%, Neutral: 4.0%, Negative: 2.0%
# Most Confident Reviews:
# 1. beautiful shoe and really comfortable
# 2. Great shoe very stylish
# 3. Beautiful shoe and good quality
# 4. Nice quality shoe. I’d definitely recommend to others.
# 5. Beautiful shoes. Stunning, head-turner and true to size. Very comfortable also.
#
#
# Topic Name and Number: 19_love_them_absolutely_are
# Review count - 99
# Keywords - ['love', 'them', 'absolutely', 'are', 'expensive', 'else', 'beautiful', 'these', 'gorgeous', 'price']
# Sentiment distribution: Positive: 99.0%, Neutral: 0.0%, Negative: 1.0%
# Most Confident Reviews:
# 1. So glad I picked these! LOVE them
# 2. Love love love them !
# 3. I absolutely love these
# 4. Greetings- Love them!
# 5. They are great, love them!
#
#
# Topic Name and Number: 20_11_10_size_12
# Review count - 92
# Keywords - ['11', '10', 'size', '12', 'ordered', 'too', 'small', 'an', 'shoe', 'but']
# Sentiment distribution: Positive: 42.4%, Neutral: 26.1%, Negative: 31.5%
# Most Confident Reviews:
# 1. I love, love these shoes but the size 11 were too short (I usually wear 10. 5 or 11) I am disappointed but that’s ok
# 2. I really wanted these to work, they are very stiff and have no give. I usually wear an 11 and that’s what size I purchased, but they seem a little small. Unfortunately I have wore them once so can’t return them- they also left significant marks on the top of my foot.
# 3. I'm a first time shopper and this beautiful shoe is not a true size 11. It was too snug on my feet. I gave it to someone who wears size 10.
# 4. I ordered a 12 and it's really short...my toes hang off.
# 5. My daughter takes a size 11 and these still slip off her feet.
#
#
# Topic Name and Number: 21_sneakers_are_love_these
# Review count - 91
# Keywords - ['sneakers', 'are', 'love', 'these', 'new', 'gum', 'they', 'and', 'comfortable', 'style']
# Sentiment distribution: Positive: 97.8%, Neutral: 0.0%, Negative: 2.2%
# Most Confident Reviews:
# 1. I’m happy with these sneakers. They are very cute on the outside. Nice and squishy on the inside. And polished enough to wear on the streets…not to the gym. I was actually stopped by a young shopkeeper on Madison Avenue who admired them and wanted to know what brand they were. Keepers!
# 2. I absolutely love these sneakers they are comfortable and cute
# 3. 4th pair of S. M. Sneakers. comfortable… Love each pair. ❤️
# 4. Love my new sneakers! They are so comfortable to wear! Plus you can dress them up and down
# 5. These sneakers are the most comfortable shoes I’ve ever worn. Love them!
#
#
# Topic Name and Number: 22_calves_calf_wide_have
# Review count - 87
# Keywords - ['calves', 'calf', 'wide', 'have', 'not', 'fit', 'calfs', 'tight', 'but', 'barely']
# Sentiment distribution: Positive: 59.8%, Neutral: 18.4%, Negative: 21.8%
# Most Confident Reviews:
# 1. Super cute but not for girls with thick calves. I have super muscular calves and I’m not super large so I thought they would fit and fit they did not. They hit right at the thickest part of my calf. :( so sad I had to return
# 2. These look so good and I can’t wait to wear them. Although I don’t consider myself to have a big calf, I had to get the wide calf ones because the others ones would not zip.
# 3. They fit so well! Perfect for wide calves and they’re comfortable 🤠
# 4. Fit a bit snug around calf but I’m sure over time that will be fine. I feel like a Bratz doll when I wear them.
# 5. They look amazing and fits comfortably. The height is great. It is able to stretch over my wide calfs without any problem. The texture of the material is smooth and soft.
#
#
# Topic Name and Number: 23_heels_kitten_sexy_these
# Review count - 84
# Keywords - ['heels', 'kitten', 'sexy', 'these', 'love', 'your', 'for', 'perfect', 'wedding', 'comfortable']
# Sentiment distribution: Positive: 91.7%, Neutral: 4.8%, Negative: 3.6%
# Most Confident Reviews:
# 1. These heels are stunning! Great fit and elevate any outfit.
# 2. Love these heels! Perfect for casual wear and dressing up 💘
# 3. Fav heels ! I think they are timeless and very comfortable
# 4. I love these heels! They are very nice. I love them.
# 5. I love my new block heels, super sexy and comfortable. Can't wait for a date night..
#
#
# Topic Name and Number: 24_cute_comfortable_super_comfy
# Review count - 84
# Keywords - ['cute', 'comfortable', 'super', 'comfy', 'very', 'and', 'adorable', 'so', 'anything', 'wouild']
# Sentiment distribution: Positive: 95.2%, Neutral: 4.8%, Negative: 0.0%
# Most Confident Reviews:
# 1. Super cute and comfortable
# 2. Cute and comfortable!
# 3. Super cute and very comfortable
# 4. Cute and very comfortable
# 5. cute and very comfortable
#
#
# Topic Name and Number: 25_purse_it_this_its
# Review count - 80
# Keywords - ['purse', 'it', 'this', 'its', 'wallet', 'purses', 'just', 'match', 'matching', 'is']
# Sentiment distribution: Positive: 83.8%, Neutral: 11.2%, Negative: 5.0%
# Most Confident Reviews:
# 1. This purse is stunning well made and just beautiful
# 2. I love i love this purse i love the sliver chain i just love everything about it
# 3. Purse is absolutely beautiful. I also purchased the purse charm to go with it!
# 4. OMG!!!!! Such a great purse I absolutely love it. Love the silver accents. The chain is great quality!
# 5. It ripped from one of the sides straps where it connects to the purse.
#
#
# Topic Name and Number: 26_fit_perfectly_them_perfect
# Review count - 76
# Keywords - ['fit', 'perfectly', 'them', 'perfect', 'they', 'husband', 'loved', 'glove', 'like', 'great']
# Sentiment distribution: Positive: 96.1%, Neutral: 2.6%, Negative: 1.3%
# Most Confident Reviews:
# 1. Wife loves them, beautful and perfect fit. Great service and fast shipping. Thank you!
# 2. Really like these. Fit well
# 3. They fit perfectly. Look exceptional good. Very well put together on looks and style. On point! Thanks Steve Madden.
# 4. They fit well. Look great
# 5. They fit so well, the suede is beautiful and soft, the silver hardware is heavy-duty and shiny. 11/10
#
#
# Topic Name and Number: 27_loves_she_gift_granddaughter
# Review count - 69
# Keywords - ['loves', 'she', 'gift', 'granddaughter', 'daughter', 'christmas', 'loved', 'her', 'them', 'for']
# Sentiment distribution: Positive: 98.6%, Neutral: 1.4%, Negative: 0.0%
# Most Confident Reviews:
# 1. I bought these for my daughter and she loves them.
# 2. I don't have specifics as I bought these as a gift for my neice. But she said "I love them! I'm obsessed!"
# 3. They are a Christmas gift
# 4. My daughter loves these!
# 5. Gift for granddaughter she loves them.
#
#
# Topic Name and Number: 28_shoe_this_is_comfortable
# Review count - 66
# Keywords - ['shoe', 'this', 'is', 'comfortable', 'versatile', 'looks', 'stylish', 'sexy', 'ages', 'love']
# Sentiment distribution: Positive: 100.0%, Neutral: 0.0%, Negative: 0.0%
# Most Confident Reviews:
# 1. I think the shoe is so sleek & sexy.. love it
# 2. This shoe is so comfortable and stylish!
# 3. I really like the looks of the shoe it’s just that is heavy, but I still like it
# 4. I really like this shoe comfortable and affordable
# 5. Such a beautiful shoe! Always get compliments when I wear this shoe but definitely more of a sitting shoe (iykyk). I do have flat feet so if you don't it may be more comfortable for you.
#
#
# Topic Name and Number: 29_comfortable_beautiful_very_nice
# Review count - 66
# Keywords - ['comfortable', 'beautiful', 'very', 'nice', 'quality', 'great', 'price', 'good', 'and', 'worth']
# Sentiment distribution: Positive: 98.5%, Neutral: 0.0%, Negative: 1.5%
# Most Confident Reviews:
# 1. Beautiful and comfortable
# 2. Beautiful and comfortable
# 3. Beautiful and comfortable
# 4. Beautiful and very comfortable
# 5. Unique look. Comfortable.
#
#
# Topic Name and Number: 30_black_brown_as_in
# Review count - 61
# Keywords - ['black', 'brown', 'as', 'in', 'them', 'bought', 'pair', 'ones', 'white', 'color']
# Sentiment distribution: Positive: 85.2%, Neutral: 4.9%, Negative: 9.8%
# Most Confident Reviews:
# 1. Love them!!
# Wish you had black
# 2. I would buy the black ones too!
# 3. Love them! Don’t have to worry about matching them since they are black & go with everything 🖤
# 4. First saw these as NB but being that I like SM so much I decided to purchase it here. Purchased the black & white and the multi colored. Love it
# 5. I loved them, I previously bought some black ones and I didn't miss the opportunity to buy these in this color.
#
#
# Topic Name and Number: 31_half_up_size_12
# Review count - 60
# Keywords - ['half', 'up', 'size', '12', 'pointed', 'shoe', 'shoes', 'do', 'full', 'because']
# Sentiment distribution: Positive: 70.0%, Neutral: 25.0%, Negative: 5.0%
# Most Confident Reviews:
# 1. These shoes are incredibly cute and fashionable. I opted for a half size up, and it fits me perfectly!
# 2. Love how these look
# Very cute and fashionable
# Only downside is that you will not be able to walk long distances with these, especially since they’re a little bit tighter around the toes which caused my feet to have a little redness
# I think I went up a half size because they do run smaller imo
# 3. The shoes look great and all that but they definitely run a half size too big. Because of the poor sizing the shoe just didn't fit right and the tweed material scratched at my skin almost like a rug burn.
# 4. They are very cute and very well made but they are way chunkier than I expected. I’m usually a 9 and I bought a 9! They fit well but I do wonder if going a half size down would have been less chunky. Not sure… bought them for Europe to walk around as a cute alternative to running shoes. I definitely
# 5. These are beautiful but they run a little small. I usually wear a size 5, but these are snug. Definitely need a half size up. But I do love the color. Definitely Barbie Pink
#
#
# Topic Name and Number: 32_pair_second_my_5th
# Review count - 58
# Keywords - ['pair', 'second', 'my', '5th', 'pairs', 'two', 'this', 'another', '3rd', 'both']
# Sentiment distribution: Positive: 87.9%, Neutral: 3.4%, Negative: 8.6%
# Most Confident Reviews:
# 1. This is my second pair!! Love them!!
# 2. This is my 3rd pair and I love them!!!
# 3. Love them i have 4 pairs all different
# 4. Love these I might get another pair in the future
# 5. Never got these in the mail and they won’t send me another pair so idk why I’m being asked for a review.
#
#
# Topic Name and Number: 33_true_are_they_size
# Review count - 58
# Keywords - ['true', 'are', 'they', 'size', 'to', 'comfortable', 'up', 'maximas', 'cute', 'super']
# Sentiment distribution: Positive: 86.2%, Neutral: 6.9%, Negative: 6.9%
# Most Confident Reviews:
# 1. These are absolutely beautiful in person. They are true to size and are incredibly comfortable. Wore them on vacation and walked for hours with no discomfort.
# 2. They are super comfortable and classy at the same time. The fit is true to size
# 3. Love them super and confy and true to size
# 4. They are extremely comfortable. True to size. They literally go with everything so I’m excited to wear them this summer!
# 5. Both of my daughters love these!!! Super comfy! I think it’s a good idea to size up!
#
#
# Topic Name and Number: 34_run_small_big_they
# Review count - 57
# Keywords - ['run', 'small', 'big', 'they', 'do', 'size', 'little', 'half', 'full', 'bigger']
# Sentiment distribution: Positive: 45.6%, Neutral: 24.6%, Negative: 29.8%
# Most Confident Reviews:
# 1. Absolutely love 😍they run small size up.
# 2. I love these, they just run a little small in my opinion.
# 3. I love it just run a little bit small and i knew that and i bought half size up
# 4. I like them but they run wide.
# 5. Love them! They run a little small but think they will stretch out over time.
#
#
# Topic Name and Number: 35_madden_steve_size_shoes
# Review count - 56
# Keywords - ['madden', 'steve', 'size', 'shoes', 'usually', 'im', 'in', 'from', '12', 'small']
# Sentiment distribution: Positive: 60.7%, Neutral: 14.3%, Negative: 25.0%
# Most Confident Reviews:
# 1. I’m an 8 and have other Steve Madden shoes that are an 8 so I took a chance and ordered my true size. They just fit, the toes are a little narrow. I like the shiny material and they seem comfortable so far.
# 2. These shoes are absolutely beautiful. I’m usually a 7. 5 in most Steve Madden shoes and these fit perfectly.
# 3. I wear a size 13 and usually Steve Madden shoes fit well but these definitely came short so I needed to return them. My toes were touching the end but the width and heel were a good fit.
# The overall material and build was pretty high quality but the shiny sole exterior and the holographic material o
# 4. I wear a size 8 and I ordered a size 8 but these did not fit. I’ve never had a fit problem with Steve Madden shoes but they are made very narrow. I will be returning. Be sure to size up!
# 5. Steve Madden shoe sizes are NEVER consistent. I’m a 7 - 7-1/2 so I ordered a 7 1/2 after hearing they ran small, I couldn’t even stand comfortably in the 7 1/2 when it finally got here. Shipping was the slowest I’ve ever had from ordering online. It took six days just to ship my order then another w
#
#
# Topic Name and Number: 36_blisters_wore_hour_hours
# Review count - 56
# Keywords - ['blisters', 'wore', 'hour', 'hours', 'gave', 'blister', 'first', 'no', 'got', 'bad']
# Sentiment distribution: Positive: 44.6%, Neutral: 5.4%, Negative: 50.0%
# Most Confident Reviews:
# 1. The shoe is pretty to look at but unfortunately that’s it :(
# I was excited to finally get them in but when I wore them they left the biggest blister on the top of my foot.
# 2. Blisters on my feet after trying for 15 min
# I am a BIG fan of Steve Madden and 9/10 I am always very happy with my shoes. . . however this time I do not recommend sorry :(
# 3. Unfortunately, the other reviews were right. After sizing up a 1/2 size, I still got blisters on the sides of my feet after wearing them. These sandals are cute but disappointing that they are made too tightly. I wish I bought a similar look somewhere else.
# 4. Very comfortable and no blisters! I love these because the are just like the ones I had in the early 2000s. This show will flop like a flip flop. If that bothers you this is not a shoe for you. I normally wear a 7.5/8 and the 8 was a perfect fit!!
# 5. Will be buying these in every color. Wore them for the first time to a wedding and had no pain and no blisters. Buy these heels!
#
#
# Topic Name and Number: 37_slides_slide_these_are
# Review count - 55
# Keywords - ['slides', 'slide', 'these', 'are', 'they', 'pool', 'comfortable', 'that', 'their', 'and']
# Sentiment distribution: Positive: 90.9%, Neutral: 5.5%, Negative: 3.6%
# Most Confident Reviews:
# 1. Cute slides with the bling buckle. Can’t wait to wear them.
# 2. This slides were very cute. It was about too much designs for me but I gifted it to someone else and they absolutely loved it.
# 3. Love my floral slides. They are exactly as pictured and more comfortable than I expected!
# 4. I Love My Slides. They are well made.
# Perfect detailing. So nice!!
# 5. These slides are the cutest ever! & so comfortable. I originally ordered 1 pair, but liked it so much, ended up ordering 2 more! Highly recommend especially for the price. The perfect addition to a Summer outfit.
#
#
# Topic Name and Number: 38_color_colors_pink_want
# Review count - 55
# Keywords - ['color', 'colors', 'pink', 'want', 'nude', 'wrong', 'every', 'more', 'tan', 'please']
# Sentiment distribution: Positive: 65.5%, Neutral: 9.1%, Negative: 25.5%
# Most Confident Reviews:
# 1. I wish I could have got the other colors
# 2. Def want more in multicolors
# 3. I love so, much I have two other colors
# 4. It looks exactly like the photo. now I want all colors.
# 5. Please bring back the white distressed Rocky
#
#
# Topic Name and Number: 39_small_runs_run_shoe
# Review count - 55
# Keywords - ['small', 'runs', 'run', 'shoe', 'but', 'send', 'shoes', 'little', 'whole', 'up']
# Sentiment distribution: Positive: 52.7%, Neutral: 32.7%, Negative: 14.5%
# Most Confident Reviews:
# 1. These shoes are beautiful but run very small. Unfortunately I’ll be returning mine.
# 2. Beautiful shoes but runs small and the band has no extension
# 3. This shoes runs extremely large
# 4. They are really cute shoes but they do run kind of small
# 5. I love the shoe very beautiful but it ran small
#
#
# Topic Name and Number: 40_walk_easy_walking_hard
# Review count - 54
# Keywords - ['walk', 'easy', 'walking', 'hard', 'to', 'in', 'off', 'put', 'comfortable', 'on']
# Sentiment distribution: Positive: 77.8%, Neutral: 16.7%, Negative: 5.6%
# Most Confident Reviews:
# 1. Easy to walk in. Very comfortable. Can wear with anything.
# 2. Super comfortable and I got so many compliments not to high so it’s easy to walk in
# 3. Super easy to walk in and classy!
# 4. Very comfortable. Easy to walk in.
# 5. Comfortable and easy to walk with
#
#
# Topic Name and Number: 41_yet_havent_worn_them
# Review count - 54
# Keywords - ['yet', 'havent', 'worn', 'them', 'cant', 'wait', 'look', 'wear', 'wore', 'dress']
# Sentiment distribution: Positive: 87.0%, Neutral: 5.6%, Negative: 7.4%
# Most Confident Reviews:
# 1. They look just like the picture. I haven't worn them yet
# 2. Haven't had a chance to wear them but I love the look.
# 3. I haven't worn them yet
# 4. Haven't worn yet but I did try them on and they are just perfect!
# 5. Like the look haven't worn them yet
#
#
# Topic Name and Number: 42_dress_skirt_waist_medium
# Review count - 53
# Keywords - ['dress', 'skirt', 'waist', 'medium', 'this', 'it', 'length', 'flattering', 'material', 'is']
# Sentiment distribution: Positive: 83.0%, Neutral: 13.2%, Negative: 3.8%
# Most Confident Reviews:
# 1. Fits perfectly! I wear size 6 & I can’t wear it to my wedding! It matches my dress perfectly.
# 2. I seen the model on the webpage where it so I bought it and like them have not worn the outfit yet but will
# 3. Perfect for my mocha prom dress!
# 4. I love this dress. The material is very soft to the touch and it's not thin, and the beige color is a must have. I love it!!
# 5. This dress is very flattering and perfect for Fall
#
#
# Topic Name and Number: 43_leather_soft_quality_smell
# Review count - 53
# Keywords - ['leather', 'soft', 'quality', 'smell', 'nice', 'faux', 'is', 'classic', 'eight', 'puffy']
# Sentiment distribution: Positive: 81.1%, Neutral: 15.1%, Negative: 3.8%
# Most Confident Reviews:
# 1. Love the fit and the leather on a soft!!!
# 2. Beautiful and comfortable the leather is so soft.
# 3. Nice fit, soft leather with a little padding
# 4. Leather is of good quality. Fit is a little narrow, size 1/2 up. Cushion is good with a small amount of arch support.
# 5. Great quality, true to size, really nice leather.
#
#
# Topic Name and Number: 44_brown_black_boots_color
# Review count - 52
# Keywords - ['brown', 'black', 'boots', 'color', 'pair', 'the', 'colored', 'in', 'suede', 'confort']
# Sentiment distribution: Positive: 84.6%, Neutral: 11.5%, Negative: 3.8%
# Most Confident Reviews:
# 1. I love my bone colored “Lasso” boots but hadn’t seen them in brown distressed color until I visited the website. I just had to have them as well! Absolutely love the color, styling, and fit of these boots. So sexy and empowering to walk around in but comfortable enough to walk around in them all day
# 2. I love these boots! I have them in denim and the brown suede. I plan on purchasing the brown distress pair too!
# 3. I live that this bit has two colors. However, the description says brown and red. Then it actually looks like back and brown (see picture). I wish it was more red and more brown. Lol. However I have been eyeing the lasso boots forever and settled with this and I love them! Can't wait to wear for the
# 4. I love the wide leg and true leather of the boots. The black is a true black color. The style is easy enough to change outfits with, and the quality of the leather is great. The only downfall was I needed more support inside the boot.
# 5. Love the color and style so much. I ordered it in brown and black. The brown ones are just as nice. I love both of the boots will not be returning either one. They were worth every dime !
#
#
# Topic Name and Number: 45_half_size_up_bigger
# Review count - 49
# Keywords - ['half', 'size', 'up', 'bigger', '12', 'ordered', 'went', 'small', 'sizes', 'down']
# Sentiment distribution: Positive: 61.2%, Neutral: 20.4%, Negative: 18.4%
# Most Confident Reviews:
# 1. These are gorgeous and fit great! I read the reviews, ordered 1/2 size up and they fit great! I love them!
# 2. These are great I ordered a half size up.
# 3. Go half size up love love the quality very comfortable and sexy. Don’t roll down at all
# 4. I love these!! Buy the
#  You won't regret it. I sized down 1/2 size. i
# 5. I would order a half size down
#
#
# Topic Name and Number: 46_calves_calf_boots_calfs
# Review count - 48
# Keywords - ['calves', 'calf', 'boots', 'calfs', 'have', 'fit', 'skinny', 'wide', 'if', 'are']
# Sentiment distribution: Positive: 68.8%, Neutral: 20.8%, Negative: 10.4%
# Most Confident Reviews:
# 1. Cutest rain boots ever! I searched everywhere for cute rain boots and was so excited when I found these. Unfortunately though my calves are too big for them even when I loosen the buckle. So if you have bigger calves these probably won’t fit comfortably. I’m also in between sizes so I sized up but s
# 2. Love these boots. Perfect for my skinny calfs. Very comfortable too.
# 3. Was looking everywhere for knee high boots that would fit my skinny calfs, and these fit perfectly! Going to be a fall staple in my wardrobe!
# 4. Love the boots but these are NOT a dupe for the Frey boots. I really wanted these to look like the picture but unfortunately they are tight to the calf (and I feel like I have average size calves). Wish they came in wide calf!!
# 5. These are first pair of regular boots that actually fit my wide, muscular calfs.
# I have also ordered the the cognac and red ones.
# Check out my IG to see the review @ap_beautifully_stylied.
# Steve Madden I would love to sit with y’all because I have a design in mind for a different pair that would
#
#
# Topic Name and Number: 47_quality_product_good_great
# Review count - 48
# Keywords - ['quality', 'product', 'good', 'great', 'price', 'value', 'style', 'amazing', 'application', 'coloir']
# Sentiment distribution: Positive: 97.9%, Neutral: 0.0%, Negative: 2.1%
# Most Confident Reviews:
# 1. Woow. The quality is super. Very beautiful
# 2. Great value. Looks Great!
# 3. Great quality especially for the price!
# 4. great quality for price
# 5. I feel so cool and effortless when I put this one, the quality is amazing as always!!
#
#
# Topic Name and Number: 48_stylish_comfortable_very_spin
# Review count - 45
# Keywords - ['stylish', 'comfortable', 'very', 'spin', 'hr', 'apres', 'and', 'comfort', 'warm', 'streaks']
# Sentiment distribution: Positive: 95.6%, Neutral: 2.2%, Negative: 2.2%
# Most Confident Reviews:
# 1. Very comfortable and stylish
# 2. Very stylish and comfortable
# 3. Very stylish, surprisingly comfortable, I had no issues and I would buy again!
# 4. Just as I expected, very stylish and comfortable
# 5. Nice, comfortable and stylish
#
#
# Topic Name and Number: 49_95_12_10_big
# Review count - 44
# Keywords - ['95', '12', '10', 'big', 'too', 'ordered', 'small', 'returned', 'reviews', 'size']
# Sentiment distribution: Positive: 54.5%, Neutral: 13.6%, Negative: 31.8%
# Most Confident Reviews:
# 1. I'm a true 9, I get 9.5 in pointy toes just for comfort, but had to return these for a 10 so I'd suggest going up a full size. I'm not sure why I'm seeing mostly "runs large" but ain't no way. Other than that they seem very comfortable and sexy. I haven't worn them yet.
# 2. These run a half size too big. They run longer not wider!! I wear a 9/9.5. I brought a size 9 based on the reviews. Ever so slightly a bit long. I have a wide foot. I needed shoe stretch for the first strap that goes across the toes. These are leather so they were easy to break in.
# 3. I bought these shoes in a size 9 first. They were too small, so I then bought them in a 9.5 and they are still too small. No difference between the 9 and 9.5. Very disappointing.
# 4. My usual shoe size is 8. 5. Based on online reviews, I decided to size up and order a 9. However, the size 9 proved to be too tight. I'm now returning them to exchange for a 9. 5, in hopes of finding a more comfortable fit. As I haven't been able to walk in them, I can't yet speak to the shoe's
# 5. I got these despite the bad reviews and love them! For reference, I am typically a size 9. 5, but I got a size 10, and they fit perfectly. I do have a narrow foot so that factors in. But for me personally, they fit perfectly!
#
#
# Topic Name and Number: 50_runs_small_cute_big
# Review count - 44
# Keywords - ['runs', 'small', 'cute', 'big', 'large', 'but', 'run', '28', 'clunky', 'shorter']
# Sentiment distribution: Positive: 59.1%, Neutral: 38.6%, Negative: 2.3%
# Most Confident Reviews:
# 1. Runs small but cute for price
# 2. cute and comfy, but runs a size small.
# 3. Super cute. Run smaller so make sure to size up at least a half size!
# 4. Very pretty but runs small so had to return
# 5. Very cute, love it... runs small
#
#
# Topic Name and Number: 51_jacket_coat_this_it
# Review count - 44
# Keywords - ['jacket', 'coat', 'this', 'it', 'cozy', 'sleeves', 'button', 'is', 'boxy', 'oversized']
# Sentiment distribution: Positive: 86.4%, Neutral: 4.5%, Negative: 9.1%
# Most Confident Reviews:
# 1. Loving my varsity jacket. Had to reorder for a larger size. It fits perfectly now.
# 2. This jacket is very cute. Feels good and is comfortable. I’m normally a XL… I ordered both XL and XXL and the XL was perfect.
# 3. Wanted to love this jacket. I can usually wear a large in any women’s jacket, this one looked silly on me🎃
# 4. Cute jacket but I did not like it the fit, it’s too short and boxy and I did not care for the fabric😏
# 5. This jacket is too cutsie! It runs true to size I wish the sleeves were longer for us tall girlies. It’s great quality and color is vibrant.
#
#
# Topic Name and Number: 52_height_boots_heel_shorter
# Review count - 41
# Keywords - ['height', 'boots', 'heel', 'shorter', 'knee', 'tall', 'leg', 'perfect', 'these', 'high']
# Sentiment distribution: Positive: 97.6%, Neutral: 2.4%, Negative: 0.0%
# Most Confident Reviews:
# 1. Love these boots! Great fit (tts) and heel height is perfect. Highly recommend!
# 2. These boots are gorgeous and comfortable. The material is buttery soft and looks like real leather. The heel height is good to elongate your legs. Fits well on the leg with no gaps at the top. Beautiful style. I need these in brown now. ♥️
# 3. Obsessed with these boots! I love the fit and the height they give me!
# 4. These boots are amazing. Heel not too high and comfortable. Boots are great quality and comes up past my mid thigh. Can’t wait to wear them.
# 5. Got so many compliments in these boots. They are thick thigh friendly. The heel is the perfect height for these to be worn all day long. The bottom of the shoe isn't made with that slippery material which makes it the perfect boot to wear anywhere.
#
#
# Topic Name and Number: 53_platform_platforms_high_flat
# Review count - 40
# Keywords - ['platform', 'platforms', 'high', 'flat', 'being', 'they', 'weight', 'some', 'makes', 'of']
# Sentiment distribution: Positive: 85.0%, Neutral: 5.0%, Negative: 10.0%
# Most Confident Reviews:
# 1. I had big hopes for these platforms. They are cute, however, very uncomfortable. The metal peices joining the braided straps dug into my feet. Also, sole were too stiff.
# 2. Really like these platforms with a great 70’s vibe. They fit just right. Now just to wait for warmer weather!
# 3. I really liked these! They don't have a platform however they are comfortable and very stylish!
# 4. Fun sexy and easy to walk in - bomb platforms for petite girlies!
# 5. The platform makes these really walkable even though they’re really high. Love them!
#
#
# Topic Name and Number: 54_75_am_im_usually
# Review count - 39
# Keywords - ['75', 'am', 'im', 'usually', 'up', '65', 'in', 'shoe', 'but', 'size']
# Sentiment distribution: Positive: 76.9%, Neutral: 5.1%, Negative: 17.9%
# Most Confident Reviews:
# 1. I was iffy about the sizing and went in store to try them on. They’re sooo cute! But definitely size up. I’m usually a 7 in other sandals and heels and had to get a 7. 5 in these.
# 2. Beautiful shoe! They were very slippery when I first tried them on, but the more you wear them out they create a tread on the bottom and don’t stay slippery. I will say length wise they seem a little shorter than normal. I’m a true 7, and my heel came right up to the edge but I know a size up would
# 3. Shoes run super small but are the comfiest shoes ever!! I am a true 7 and had to order a size 8.
# 4. These shoes are so cute and unique!! They are relatively comfortable considering the heel height, and style of the shoe. I am a true size 7 in most shoe brands but always take a 7. 5 in SM.
# 5. These shoes are gorgeous. They run a little small, I’m a 7 and it was a perfect fit, I like a bit of room in my shoes, so I am reordering in a 7.5.
# They are stunning on and will work with so many things in your closet.
#
#
# Topic Name and Number: 55_sneaker_good_office_several
# Review count - 38
# Keywords - ['sneaker', 'good', 'office', 'several', 'is', 'looks', 'comfortable', 'that', 'stylish', 'great']
# Sentiment distribution: Positive: 92.1%, Neutral: 7.9%, Negative: 0.0%
# Most Confident Reviews:
# 1. Nice sneaker and love the color
# 2. Beautiful sneaker! I love it!
# 3. I love the sneaker. Very stylish and comfortable
# 4. I brought these for my daughter for a sneaker ball they were everything I expected it
# 5. Nice and comfy sneaker
#
#
# Topic Name and Number: 56_true_cute_size_super
# Review count - 38
# Keywords - ['true', 'cute', 'size', 'super', 'to', 'comfy', 'accurate', 'charming', 'sisterinlaw', 'sizecant']
# Sentiment distribution: Positive: 97.4%, Neutral: 2.6%, Negative: 0.0%
# Most Confident Reviews:
# 1. So comfy and cute. Runs true to size
# 2. Comfy cute and true to size ♥️
# 3. So cute and comfy! Didn’t need to break in and true to size!
# 4. True to size, comfy and so cute!
# 5. True to size very cute and comfortable
#
#
# Topic Name and Number: 57_daughter_shoes_loves_her
# Review count - 38
# Keywords - ['daughter', 'shoes', 'loves', 'her', 'took', 'granddaughter', 'she', 'mother', 'for', 'my']
# Sentiment distribution: Positive: 73.7%, Neutral: 7.9%, Negative: 18.4%
# Most Confident Reviews:
# 1. Delivery and shipment was not good, my shoes werent delivered on time. I love the shoes!
# 2. It took rather long to receive the shoes being that the size was hard to find in warehouse per the rep I spoke with but it was worth the wait. I like the color & stylist look of the slippers which can be pair with many outfits.
# 3. The minute my daughter say the shoes with matching bag. My other daughter asked for one for her Birthday
# 4. I love the shoes so much I preordered them in September. Shipping got pushed back 3 times. I just recorded them in January.
# 5. Purchased these for my daughter who adores them. They’re perfect for the he holiday season. Shipping was prompt, shoes carefully packaged and crystals applied all over the shoes were very well done.
#
#
# Topic Name and Number: 58_gift_she_daughter_it
# Review count - 37
# Keywords - ['gift', 'she', 'daughter', 'it', 'loved', 'xmas', 'christmas', 'loves', 'bought', 'present']
# Sentiment distribution: Positive: 86.5%, Neutral: 8.1%, Negative: 5.4%
# Most Confident Reviews:
# 1. My daughter wanted one for Christmas since it’s still going viral on tic toc so I hope she’ll love it
# 2. It’s a Christmas gift!!!! I can’t give a review.
# 3. This is Christmas gift to my granddaughter,17yrs. She loved it.
# 4. My daughter is 33, she loves it!
# 5. Bought for engagement photos. SO SO CUTE ANF WORTH IT
#
#
# Topic Name and Number: 59_85_size_shoe_am
# Review count - 36
# Keywords - ['85', 'size', 'shoe', 'am', 'true', 'ppl', 'fit', 'but', 'ordered', 'shoes']
# Sentiment distribution: Positive: 69.4%, Neutral: 19.4%, Negative: 11.1%
# Most Confident Reviews:
# 1. 8. 5- True to size, sturdy but comfortable. Velcro straps make it easy to adjust to your feet. Beautiful shoes to slide on and go about your day. Looks even better in person.
# 2. Love how they look but do run small and were very uncomfortable to wear at first. I’m normally a size 8/8. 5 but had to get a size 9. Did take a while to break into them too. Got a blister on each foot where the sandal rubs on the side
# 3. Very nice design. I got a size 8.5 but my feet still don’t feel comfortable (I had to stretch them out using a thick sock). They are snug now, though, not everyone would do the method I did.
# 4. Beautiful shoe; however run small. I normally wear a 7. 5 or 8 and decided to go with the 8. I had to exchange for a size 9.
# 5. Amazing shoes - I always order a size 8 and these are true to size with me. Not confining on the toes and a solid grip. Just wish they had more traction on the bottom of the shoe but I can buy a traction pad and add on.
#
#
# Topic Name and Number: 60_loafers_loafer_classic_were
# Review count - 34
# Keywords - ['loafers', 'loafer', 'classic', 'were', 'madison', 'looking', 'both', 'first', 'red', 'olive']
# Sentiment distribution: Positive: 85.3%, Neutral: 5.9%, Negative: 8.8%
# Most Confident Reviews:
# 1. Nice loafers
# Great quality
# Found them to be on the narrow side
# Size was perfect
# Width: too narrow
# 2. Hurts so bad and was hoping theyll break in to my fit but have not and so upset because i was so excited to wear them and feel like i either need a bigger size or different loafer ;(
# 3. Perfect white loafer well styled and great fit.
# 4. I absolutely love my loafers I got a ton of compliments on them at work
# 5. Needed to replace an older animal print loafer and these were exactly what I was looking for and they were comfortable!!!
#
#
# Topic Name and Number: 61_compliments_many_received_lots
# Review count - 33
# Keywords - ['compliments', 'many', 'received', 'lots', 'lot', 'got', 'tons', 'cutereceived', 'undeniably', 'sassyso']
# Sentiment distribution: Positive: 100.0%, Neutral: 0.0%, Negative: 0.0%
# Most Confident Reviews:
# ...
# Review count - 15
# Keywords - ['feet', 'looks', 'focus', 'puts', 'comfy', 'stunning', '2x', 'nice', 'foot', 'negative']
# Sentiment distribution: Positive: 73.3%, Neutral: 20.0%, Negative: 6.7%
# Most Confident Reviews:
# 1. Not as attractive on my foot as I'd hoped. The opening across the foot puts too much focus on my toes.
# 2. Looks great on the feet. Seem very comfy
# 3. Beautiful on the foot
# 4. Absolutely stunning and so very comfy!!! If you have a wide foot size up a half size.
# 5. This is not only stunning, it is comfortable on my feet!
#
#
# Topic Name and Number: 95_stylish_cute_leisure_conversation
# Review count - 15
# Keywords - ['stylish', 'cute', 'leisure', 'conversation', 'versatile', 'errands', 'convenient', 'exceeded', 'styled', 'expectations']
# Sentiment distribution: Positive: 100.0%, Neutral: 0.0%, Negative: 0.0%
# Most Confident Reviews:
# 1. Very cute and stylish! Great for errands and everyday wear- can be styled with jeans or leisure wear.
# 2. Very cute and stylish.
# 3. It’s super cute and stylish ❤️❤️
# 4. So cute and are so versatile, expectations exceeded
# 5. So cute and stylish !
#
#
# Topic Name and Number: 96_it_miu_dupe_herself
# Review count - 15
# Keywords - ['it', 'miu', 'dupe', 'herself', 'steallll', 'spins', 'kill', 'reminds', 'bill', 'worth']
# Sentiment distribution: Positive: 100.0%, Neutral: 0.0%, Negative: 0.0%
# Most Confident Reviews:
# 1. I loved it but I haven’t used it yet but loved it.
# 2. great miu miu dupe. 10/10 recommend.
# 3. It’s freaking fantastic it spins heads
# 4. i’m honestly so impressed. definitely worth it!! such a steallll
# 5. I ABSOLUTELY LOVE IT ! HIGHLY RECOMMEND
#
#
# Topic Name and Number: 97_height_wedding_beaut_mildly
# Review count - 14
# Keywords - ['height', 'wedding', 'beaut', 'mildly', 'problem', '72', 'regardless', 'courthouse', 'dillards', 'wearing']
# Sentiment distribution: Positive: 100.0%, Neutral: 0.0%, Negative: 0.0%
# Most Confident Reviews:
# 1. Love them , gives you a inch or two in height , very comfortable dont slip off your feet
# 2. Love love love.
# Run true to size and they just make me fell “classy “ when I wear them.
# I’m 72 but have no problem with the height
# 3. Perfect for my outfit and quite comfortable, regardless of the height.
# 4. I haven’t wore these yet, but tried them on and they’re a keeper. Perfect height, not too tall and not too short. Will look great with my summer dresses.
# 5. so comfortable perfect height! wore them for hours and was perfectly comfortable!!
#
#
# Topic Name and Number: 98_shows_show_dear_studds
# Review count - 14
# Keywords - ['shows', 'show', 'dear', 'studds', 'planet', 'drawback', 'warmth', 'protect', 'remind', 'childhood']
# Sentiment distribution: Positive: 100.0%, Neutral: 0.0%, Negative: 0.0%
# Most Confident Reviews:
# 1. Love this show! Comfort, style and quality product! My only drawback is that I have a high instep, so the velcro strap could've been longer.
# 2. This show is a perfect addition to my wardrobe. The pink goes with many outfits. Love it.
# 3. Love these shows they remind me of my childhood and there comfortable. . buy before there gone
# 4. Love this show! It’s gorgeous and comfortable. The only thing I don’t love is that the footbed is pretty narrow at the front.
# 5. Fav white shows in the planet. They make every outfit look that fabulous. So comfortable, so stylish, yet so classic, and for sure, a basic that you need. Get them! Need more colors dear Steve! 🥹
#
#
# Topic Name and Number: 99_socks_count_soft_say
# Review count - 14
# Keywords - ['socks', 'count', 'soft', 'say', 'invisible', 'bootheels', 'colours', 'xox', 'lookalikes', 'thin']
# Sentiment distribution: Positive: 92.9%, Neutral: 0.0%, Negative: 7.1%
# Most Confident Reviews:
# 1. They look beyond amazing and they are super comfortable. I was a little nervous about if I’d be able to wear socks with them because of the boot fitting like a glove. I CAN!! This will definitely be my go to dressy winter boot/heels.
# 2. Feels comfy. A little big, but I don’t wear with socks. Looks great. Not bad for price and appears well made. I can always count on this brand. I think it’s worth paying a few more $ vs. Amazon lookalikes, because you can count on the quality.
# 3. What is there to say? Comfortable no show socks. Fits nicely and invisible with shoes.
# I would purchase again.
# 4. Very soft and cozy socks. Nice retro look. Will be buying more, although they only come in the green strip. Please add more colors :)
# 5. These socks are made very well. They have great quality to them. Very comfortable.
#
#
# Topic Name and Number: 100_booties_boot_gras_mardi
# Review count - 14
# Keywords - ['booties', 'boot', 'gras', 'mardi', 'wait', 'patent', 'red', 'float', 'heaven', 'pointier']
# Sentiment distribution: Positive: 92.9%, Neutral: 7.1%, Negative: 0.0%
# Most Confident Reviews:
# 1. OBSESSED WITH THIS BOOT!! I live in NYC and seriously wear this thing everywhere. 1000/10.
# 2. Love the boot. I wore them with my Mardi Gras outfit on a float in the Mardi Gras parade. I received lots of comments
# 3. Love these booties. Very comfy to wear and I love the blue color. This comes from a guy that likes to wear heels. It's a part of my lifestyle.
# 4. I love my booties! They are show stoppers!! They're fairly comfortable too!
# 5. The quality of the leather and comfort of the boot makes it a fashion fav for me. I also ordered the brown suede pair as well.
#
#
# Topic Name and Number: 101_sm_horn_ive_ankle
# Review count - 13
# Keywords - ['sm', 'horn', 'ive', 'ankle', 'adequate', 'inconsistency', 'dependent', 'cancer', 'lesson', 'hasnt']
# Sentiment distribution: Positive: 38.5%, Neutral: 15.4%, Negative: 46.2%
# Most Confident Reviews:
# 1. I ordered 2 sizes of this style knowing that SM runs a little big on me. The largest size had ankle straps that had to be on the last hole, causing the studs to stop half way around my ankle and were still tight. The smaller size had adequate ankle strap length that were visibly inches longer than o
# 2. I originally ordered my usual SM size and this shoe was too big I exchanged for a smaller size and the length is good but the width is too wide and my feet slide out the front of shoe. SM sizing is inconsistent and they make you pay a restocking fee to return. Lesson learned, I will never order from
# 3. I’ve been looking to buy this style of shoe. Of course SM came through! Perfect look and fit.
# 4. Other sizes are too small for SM for me, but these fit perfect! I’ve been wearing them with everything, obsessed!
# 5. I’m disappointed because I don’t usually have an issue with SM shoes. But these were not gonna work for my wider feet.
#
#
# Topic Name and Number: 102_jeans_dresses_skirts_leggings
# Review count - 13
# Keywords - ['jeans', 'dresses', 'skirts', 'leggings', 'styled', 'with', 'skirt', 'daughter', 'shorts', 'pursue']
# Sentiment distribution: Positive: 100.0%, Neutral: 0.0%, Negative: 0.0%
# Most Confident Reviews:
# 1. My daughter got me these for my birthday and they’re so comfortable, stylish and looks good with denim dresses, denim goucho shorts, wide leg jeans. I will wear these all summer long. Oh and not to high and the suede chef kiss❤️
# 2. These are really cute and looked good with skirt, sundress and jeans
# 3. Love these, I wear them with jeans. So cute
# 4. Need a little wearing to stretch them out a bit. But so sleek and sexy. Great with jeans, shorts, a dress or skirt. Not too high and pretty comfy considering.
# 5. Extremely cute, stylish and versatile. I can wear these however I’d like. Whether im dressing up a sweat pants outfit, a simple jeans and T type of fit, or whatevaaaa. Annndd with the matching pursue?? These pulll through!! Now, only thing I’ll say, I’m typically a 6/6.5 in women’s depending on the
#
#
# Topic Name and Number: 103_usually_luckly_comtfy_full
# Review count - 12
# Keywords - ['usually', 'luckly', 'comtfy', 'full', 'runs', 'im', 'run', '85', 'ordered', 'cute']
# Sentiment distribution: Positive: 75.0%, Neutral: 16.7%, Negative: 8.3%
# Most Confident Reviews:
# 1. Love the style, but it runs a little small. I’m usually a 7 and sized up to a 7. 5.
# 2. Very Comtfy, i love it, but runs small im 8.5 and i have to change for 9.
# 3. Ordered a 7 and it's like a 6!
# 4. Beautiful but run a bit small. I am a true 7 and had to get a 7.5.
# 5. Love! Cute and comfortable. Run slightly small. Ordered a 6. 5 and returning for a 7.
#
#
# Topic Name and Number: 104_support_arch_no_enough
# Review count - 12
# Keywords - ['support', 'arch', 'no', 'enough', 'accomplish', 'anticipate', 'actress', 'removable', 'sloped', 'product']
# Sentiment distribution: Positive: 25.0%, Neutral: 25.0%, Negative: 50.0%
# Most Confident Reviews:
# 1. Great Arch support. Very comfortable
# 2. Love then, I wish it had more support.
# 3. Super cute but the arch Support is painful
# 4. These are very stylish and had the potential to be comfortable. However the arch is sloped too steep.
# 5. No support, shoe kept coming off and too heavy with embellishments actress my toes. Unfortunately had the return.
#
#
# Topic Name and Number: 105_everything_go_yiu_literally
# Review count - 11
# Keywords - ['everything', 'go', 'yiu', 'literally', 'with', 'live', 'about', 'them', 'love', 'they']
# Sentiment distribution: Positive: 100.0%, Neutral: 0.0%, Negative: 0.0%
# Most Confident Reviews:
# 1. I love them, they go with everything
# 2. I love them, they go with everything
# 3. I love them, they go with everything
# 4. They are everything and they are amazing I love them 😍
# 5. I love them they go with everything!
#
#
# Topic Name and Number: 106_satisfied_purchase_iam_happy
# Review count - 11
# Keywords - ['satisfied', 'purchase', 'iam', 'happy', 'complain', 'with', 'complaints', 'pleased', 'am', 'buying']
# Sentiment distribution: Positive: 100.0%, Neutral: 0.0%, Negative: 0.0%
# Most Confident Reviews:
# 1. I am happy with purchased
# 2. Iam very satisfied with my purchase.
# 3. First time buying and I’m satisfied with my purchase.
# 4. Everything was great can’t complain
# 5. Very satisfied with purchase
#
#
# Topic Name and Number: 107_ballet_flats_classic_flat
# Review count - 11
# Keywords - ['ballet', 'flats', 'classic', 'flat', 'essence', 'interpretation', 'kelly', 'through', 'dressed', 'grace']
# Sentiment distribution: Positive: 100.0%, Neutral: 0.0%, Negative: 0.0%
# Most Confident Reviews:
# 1. Love these ballet flats! They run a bit small, I had to go up a size
# 2. These ballet slippers are beautiful & run true to size. They’re comfortable and true to size
# 3. I was worried about these shoes because of the poor reviews, but I ordered 1 size up (i am usually a 8 and I order a 9). They fit perfectly and I get so many compliments. They are very flat, but that's what to expect with ballet flats. I think they are super flattering and different to many other st
# 4. This ballet flat is very soft and comfortable. I love the chestnut color, and I love how versatile it is. It looks amazing with jeans or a jean dress! Lots of compliments!
# 5. i knew that i had to have these the first time i saw them. these are perfect if you want a ballet flat that isn’t boring. they are comfortable and fit true to size.
#
#
# Topic Name and Number: 108_exactly_what_expected_exceed
# Review count - 11
# Keywords - ['exactly', 'what', 'expected', 'exceed', 'description', 'described', 'wanted', 'expectations', 'wanting', 'wasnt']
# Sentiment distribution: Positive: 90.9%, Neutral: 0.0%, Negative: 9.1%
# Most Confident Reviews:
# 1. Beautiful just what I expected
# 2. Exactly as description
# 3. It was exactly what I was wanting
# 4. It wasn't what I expected.
# 5. Exactly what I expected.
#
#
# Topic Name and Number: 109_down_dress_dressed_can
# Review count - 11
# Keywords - ['down', 'dress', 'dressed', 'can', 'or', 'up', 'lowfuss', 'washing', 'flow', 'be']
# Sentiment distribution: Positive: 100.0%, Neutral: 0.0%, Negative: 0.0%
# Most Confident Reviews:
# 1. Beautiful shoes can be dressed up or down. Cannot wait to wear to an upcoming wedding!
# 2. Can dress these shoes up and down. They are comfortable and super cute
# 3. They’re so comfy and go with many out fits. You can dress up or down with these cute shoes. Very happy with my purchase!
# 4. Dress it up or down, this shoe can be worn in so many ways!! Every closet should have these!!!
# 5. These shoes are cute, comfortable & can be dressed up or down! Love!
#
#
# Topic Name and Number: 110_ittt_shot_its_loving
# Review count - 10
# Keywords - ['ittt', 'shot', 'its', 'loving', 'it', 'comfortable', 'piece', 'staple', 'surprisingly', 'gave']
# Sentiment distribution: Positive: 100.0%, Neutral: 0.0%, Negative: 0.0%
# Most Confident Reviews:
# 1. It's comfortable I like it
# 2. Love it and also comfortable
# 3. Really nice and comfortable on. This will be my Summer staple and hope this will last for a good while.
# 4. I love it! So comfortable
# 5. I love it. It’s very comfortable.
#
#
# Topic Name and Number: 111_uncomfortable_cute_extremely_waist
# Review count - 10
# Keywords - ['uncomfortable', 'cute', 'extremely', 'waist', 'but', 'weird', 'painful', 'own', 'show', 'hurt']
# Sentiment distribution: Positive: 10.0%, Neutral: 50.0%, Negative: 40.0%
# Most Confident Reviews:
# 1. Very cute but very uncomfortable.
# 2. Look cute but are uncomfortable
# 3. Looks cute but uncomfortable
# 4. So cute. But extremely uncomfortable.
# 5. Cute Cute Cute but HURT!!!
#
#
# Topic Name and Number: 112_true_rubbing_enoughhad_stroll
# Review count - 10
# Keywords - ['true', 'rubbing', 'enoughhad', 'stroll', 'foresee', 'add', 'wrinkle', 'park', 'must', 'bandaids']
# Sentiment distribution: Positive: 80.0%, Neutral: 0.0%, Negative: 20.0%
# Most Confident Reviews:
# 1. Fit true to size but just not comfortable enough-had odd rubbing on my left arch, probably due to high arches. Returned them.
# 2. Got for my daughter, size was too big from online size chart so she took to store and went a whole size down! She loves them
# 3. They fit true to size, but I can foresee the straps rubbing on my ankle. I plan to add insoles and blister bandaids so they can last me all day without discomfort.
# 4. These fit true to size and I got so many compliments!! They are also very comfortable!!
# 5. The fit is true to size. I bought them in the black and nude color. They look great on.
#
#
# Topic Name and Number: 113_catching_eye_stylish_figure
# Review count - 10
# Keywords - ['catching', 'eye', 'stylish', 'figure', 'sexy', 'totally', 'cute', 'plus', 'comfortable', 'flattering']
# Sentiment distribution: Positive: 100.0%, Neutral: 0.0%, Negative: 0.0%
# Most Confident Reviews:
# 1. Very stylish, comfortable and cute.
# 2. Cute, comfortable & fashionable!
# 3. Sexy, stylish and comfortable!!
# 4. Sexy and comfortable! Eye catching color!
# 5. Super cute and very comfy! Plus, totally stylish! 💖🫶💖
#
#
# Topic Name and Number: 114_comfy_looks_elite_image
# Review count - 10
# Keywords - ['comfy', 'looks', 'elite', 'image', 'cozy', 'amazing', 'regret', 'quality', 'fabulous', 'wasnt']
# Sentiment distribution: Positive: 100.0%, Neutral: 0.0%, Negative: 0.0%
# Most Confident Reviews:
# 1. Very comfy! Goes with everything
# 2. Very comfy and the color is beautiful
# 3. You won't regret. Super comfy
# 4. Very comfy and the quality as always good looks just like image, perfect for wedding.
# 5. Super comfy love the quality wasn’t disappointed
#    Topic Number                    Topic Name  Review Count  \
# 0             0        0_shoes_these_are_love           381
# 1             1  1_comfortable_them_comfy_are           357
# 2             2       2_boots_these_love_them           329
# 3             3    3_sandals_are_these_summer           242
# 4             4       4_wide_narrow_feet_foot           229
#
#                                             Keywords  Positive %  Neutral %  \
# 0  [shoes, these, are, love, comfortable, absolut...        95.3        3.4
# 1  [comfortable, them, comfy, are, love, cute, th...        86.3        4.2
# 2  [boots, these, love, them, are, comfortable, s...        95.4        1.8
# 3  [sandals, are, these, summer, they, comfortabl...        90.1        5.4
# 4  [wide, narrow, feet, foot, width, have, if, yo...        40.2       29.7
#
#    Negative %
# 0         1.3
# 1         9.5
# 2         2.7
# 3         4.5
# 4        30.1

# %%
# Select top 10 topics for plotting
df = topic_summary_df.head(10)

# Create grouped bar chart of sentiment percentages
fig = px.bar(df, x="Topic Name", y=["Positive %", "Neutral %", "Negative %"], barmode="group",
             color_discrete_sequence=earth_palette, title="BERTopic Sentiment Analysis")

fig = plot_preset(fig)

fig.update_layout(
    xaxis_title="Topic",
    yaxis_title="Percentage",
    legend_title="Sentiment",
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1,
        xanchor="center",
        x=0.5
    ),
    xaxis_tickangle=30,
    margin=dict(b=150, t=80)
);
